# %% [markdown]
# # Array

# %%
array=[["1","2","3","4","5","6"],["5","6","7"]]

#print(array[1][2]) #x,y
columnas=len(array[0])
print(columnas)
epa =int(input("Joaquin: ")) #7


for i in range(0,10):
    if epa<columnas:
        print(array[i][epa])
        print("Ola")
        break
    else:
        i+=1
        print(i)
        epa=epa-columnas
        print(f"epa {epa}")
        #$print(array[i][epa])
# Out:
# 6
# 1
# epa 6
# 2
# epa 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 11
#       7
#       8
#       9 for i in range(0,10):
#      10     if epa<columnas:
# ---> 11         print(array[i][epa])
#      12         print("Ola")
#      13         break
#      14     else:
#
# IndexError: list index out of range
